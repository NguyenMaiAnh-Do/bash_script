# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/ndo/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ndo/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ndo/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ndo/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/ndo/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/ndo/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
def read_vcf_with_header(vcf_file):
    """
    Read VCF file into pandas DataFrame and extract header lines.
    """
    vcf_header = []
    with open(vcf_file, "r") as f:
        for line in f:
            if line.startswith('#CHROM'):
                vcf_header.extend(line.strip().split('\t'))
    df = pd.read_csv(vcf_file, sep="\t", comment="#")
    df.columns = vcf_header
   
    return df

# %%
vcf_file = "/home/ndo/bash_output/05_bedtools_intersect/SRR13586007_intersected.vcf"
# Read VCF file into pandas DataFrame using header lines as column names
df = read_vcf_with_header(vcf_file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 3
#       1 vcf_file = "/home/ndo/bash_output/05_bedtools_intersect/SRR13586007_intersected.vcf"
#       2 # Read VCF file into pandas DataFrame using header lines as column names
# ----> 3 df = read_vcf_with_header(vcf_file)
#
# Cell In[47], line 9, in read_vcf_with_header(vcf_file)
#       7     for line in f:
#       8         if line.startswith('#CHROM'):
# ----> 9             vcf_header.extend(line.split('\t').strip().strip("#"))
#      10 df = pd.read_csv(vcf_file, sep="\t", comment="#")
#      11 df.columns = vcf_header
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
df
# Out:
#          #CHROM       POS ID REF ALT      QUAL FILTER  \
# 0          chr1    601877  .   A   C  21.18510      .
# 1          chr1    602801  .   C   G  19.87030      .
# 2          chr1    605691  .   T   C  18.68940      .
# 3          chr1    607094  .   T   G   9.53301      .
# 4          chr1    607126  .   C   A   7.13505      .
# ...         ...       ... ..  ..  ..       ...    ...
# 17540181  chr22  50793395  .   A   T  11.59980      .
# 17540182  chr22  50793407  .   A   C  11.59980      .
# 17540183  chr22  50793422  .   A   C  11.59980      .
# 17540184  chr22  50793434  .   C   G  11.59980      .
# 17540185  chr22  50793440  .   C   G  24.98420      .
#
#                                                        INFO    FORMAT  \
# 0         DP=4;SGB=-0.379885;RPBZ=1.34164;MQBZ=0.942809;...  GT:PL:AD
# 1         DP=2;SGB=-0.379885;RPBZ=-1;MQBZ=1;BQBZ=0;SCBZ=...  GT:PL:AD
# 2         DP=6;SGB=-0.379885;RPBZ=1.41421;MQBZ=1.45095;M...  GT:PL:AD
# 3         DP=2;SGB=-0.379885;RPBZ=1;MQBZ=1;MQSBZ=1;BQBZ=...  GT:PL:AD
# 4         DP=3;SGB=-0.379885;RPBZ=1.22474;MQBZ=1.41421;M...  GT:PL:AD
# ...                                                     ...       ...
# 17540181  DP=1;SGB=-0.379885;MQ0F=0;AC=2;AN=2;DP4=0,0,1,...  GT:PL:AD
# 17540182  DP=1;SGB=-0.379885;MQ0F=0;AC=2;AN=2;DP4=0,0,1,...  GT:PL:AD
# 17540183  DP=1;SGB=-0.379885;MQ0F=0;AC=2;AN=2;DP4=0,0,1,...  GT:PL:AD
# 17540184  DP=1;SGB=-0.379885;MQ0F=0;AC=2;AN=2;DP4=0,0,1,...  GT:PL:AD
# 17540185  DP=1;SGB=-0.379885;MQ0F=0;AC=2;AN=2;DP4=0,0,1,...  GT:PL:AD
#
#                        20
# 0         0/1:25,0,73:3,1
# 1          1/1:17,1,0:1,1
# 2         0/1:22,0,46:4,1
# 3           1/1:6,1,0:1,1
# 4           1/1:3,0,0:2,1
# ...                   ...
# 17540181   1/1:11,3,0:0,1
# 17540182   1/1:11,3,0:0,1
# 17540183   1/1:11,3,0:0,1
# 17540184   1/1:11,3,0:0,1
# 17540185   1/1:25,3,0:0,1
#
# [17540186 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       6     return vcf_data
#       8 vcf_file = "/home/ndo/bash_output/05_bedtools_intersect/SRR13586007_intersected.vcf"
# ----> 9 sample_df = load_sample_vcf_file(vcf_file1)
#
# Cell In[12], line 5, in load_sample_vcf_file(filename)
#       1 def load_sample_vcf_file(filename):
#       2     """
#       3     Function to load sample VCF file into a pandas DataFrame.
#       4     """
# ----> 5     vcf_data = pd.read_csv(filename, sep='\t', comment='#', header = True)
#       6     return vcf_data
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1401, in TextFileReader.__init__(self, f, engine, **kwds)
#    1398 self.nrows = options.pop("nrows", None)
#    1400 self._check_file_or_buffer(f, engine)
# -> 1401 self.options, self.engine = self._clean_options(options, engine)
#    1403 if "has_index_names" in kwds:
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1571, in TextFileReader._clean_options(self, options, engine)
#    1568 na_values = options["na_values"]
#    1569 skiprows = options["skiprows"]
# -> 1571 validate_header_arg(options["header"])
#    1573 if index_col is True:
#    1574     raise ValueError("The value of index_col couldn't be 'True'")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:208, in validate_header_arg(header)
#     206     return
#     207 if is_bool(header):
# --> 208     raise TypeError(
#     209         "Passing a bool to header is invalid. Use header=None for no header or "
#     210         "header=int or list-like of ints to specify "
#     211         "the row(s) making up the column names"
#     212     )
#     213 # GH 16338
#     214 raise ValueError("header must be integer or list of integers")
#
# TypeError: Passing a bool to header is invalid. Use header=None for no header or header=int or list-like of ints to specify the row(s) making up the column names

# %%
sample_df.head()
# Out:
#    chr1  601268  .  A  C   4.30936 ..1  \
# 0  chr1  601877  .  A  C  21.18510   .
# 1  chr1  602801  .  C  G  19.87030   .
# 2  chr1  605691  .  T  C  18.68940   .
# 3  chr1  607094  .  T  G   9.53301   .
# 4  chr1  607126  .  C  A   7.13505   .
#
#   DP=2;SGB=-0.379885;RPBZ=-1;MQBZ=-1;MQSBZ=1;BQBZ=-1;SCBZ=0;MQ0F=0;AC=1;AN=2;DP4=0,1,1,0;MQ=32  \
# 0  DP=4;SGB=-0.379885;RPBZ=1.34164;MQBZ=0.942809;...
# 1  DP=2;SGB=-0.379885;RPBZ=-1;MQBZ=1;BQBZ=0;SCBZ=...
# 2  DP=6;SGB=-0.379885;RPBZ=1.41421;MQBZ=1.45095;M...
# 3  DP=2;SGB=-0.379885;RPBZ=1;MQBZ=1;MQSBZ=1;BQBZ=...
# 4  DP=3;SGB=-0.379885;RPBZ=1.22474;MQBZ=1.41421;M...
#
#    GT:PL:AD   0/1:5,0,31:1,1
# 0  GT:PL:AD  0/1:25,0,73:3,1
# 1  GT:PL:AD   1/1:17,1,0:1,1
# 2  GT:PL:AD  0/1:22,0,46:4,1
# 3  GT:PL:AD    1/1:6,1,0:1,1
# 4  GT:PL:AD    1/1:3,0,0:2,1

# %%
import pandas as pd

def load_sample_vcf_file(filename):
    """
    Function to load sample VCF file into a pandas DataFrame.
    """
    vcf_data = pd.read_csv(filename, sep='\t', comment='#', header=None)
    # vcf_data.columns = ['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO']
    return vcf_data[['#CHROM', 'POS']]

def load_GIAB_vcf_file(filename):
    """
    Function to load sample VCF file into a pandas DataFrame.
    """
    
        vcf_data = pd.read_csv(filename, sep='\t', comment='#', header=None)
    # vcf_data.columns = ['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO']
    return vcf_data[['#CHROM', 'POS']]
def compare_vcf_files(vcf_file1, vcf_file2):
    """
    Function to compare two VCF files based on chromosome (chr) and position (pos).
    """
    vcf_data1 = load_vcf_file(vcf_file1)
    vcf_data2 = load_vcf_file(vcf_file2)
    
    # Merge the two dataframes on 'chr' and 'pos' columns
    merged_data = pd.merge(vcf_data1, vcf_data2, on=['#CHROM', 'POS'], how='inner', suffixes=('_1', '_2'))
    
    return merged_data

# Example usage:
if __name__ == "__main__":
    vcf_file1 = "/home/ndo/bash_output/05_bedtools_intersect/SRR13586007_intersected.vcf"
    vcf_file2 = "/home/ndo/GIAB-GT/HG001_GRCh38_1_22_v4.2.1_benchmark.vcf"
    
    comparison_result = compare_vcf_files(vcf_file1, vcf_file2)
    print(comparison_result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 28
#      25 vcf_file1 = "/home/ndo/bash_output/05_bedtools_intersect/SRR13586007_intersected.vcf"
#      26 vcf_file2 = "/home/ndo/GIAB-GT/HG001_GRCh38_1_22_v4.2.1_benchmark.vcf"
# ---> 28 comparison_result = compare_vcf_files(vcf_file1, vcf_file2)
#      29 print(comparison_result)
#
# Cell In[2], line 15, in compare_vcf_files(vcf_file1, vcf_file2)
#      11 def compare_vcf_files(vcf_file1, vcf_file2):
#      12     """
#      13     Function to compare two VCF files based on chromosome (chr) and position (pos).
#      14     """
# ---> 15     vcf_data1 = load_vcf_file(vcf_file1)
#      16     vcf_data2 = load_vcf_file(vcf_file2)
#      18     # Merge the two dataframes on 'chr' and 'pos' columns
#
# Cell In[2], line 9, in load_vcf_file(filename)
#       7 vcf_data = pd.read_csv(filename, sep='\t', comment='#', header=None)
#       8 # vcf_data.columns = ['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO']
# ----> 9 return vcf_data[['#CHROM', 'POS']]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['#CHROM', 'POS'], dtype='object')] are in the [columns]"
